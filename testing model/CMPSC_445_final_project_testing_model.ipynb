# %%
# block 1
# clone yolov5 from the repository
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-40-gb2a0f1c Python-3.8.16 torch-1.13.0+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.0/107.7 GB disk)

# %%
#block 2
# import all the necessary libraries
import cv2
import os
import matplotlib.pyplot as plt

# %%
#block 3
# run dete.py with already trained weights. 
# !python detect.py --weights "/content/yolov5/best.pt" --img 640 --conf 0.25 --source "/content/yolov5/test1.jpg"
image = cv2.imread(os.path.join("/content/yolov5/runs/detect/exp/test1.jpg")) # get the image from this path
plt.imshow(image)  # show the image 
plt.show()
# Out:
# detect: weights=['/content/yolov5/best.pt'], source=/content/yolov5/test1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test1.jpg: 320x640 1 honda, 198.6ms
# Speed: 1.2ms pre-process, 198.6ms inference, 22.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
#block 4
# !python detect.py --weights "/content/yolov5/best.pt" --img 640 --conf 0.25 --source "/content/yolov5/test2.png"
image = cv2.imread(os.path.join("/content/yolov5/runs/detect/exp2/test2.png"))
plt.imshow(image) 
plt.show()
# Out:
# detect: weights=['/content/yolov5/best.pt'], source=/content/yolov5/test2.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# libpng warning: iCCP: known incorrect sRGB profile
# image 1/1 /content/yolov5/test2.png: 480x640 1 BMW, 343.2ms
# Speed: 1.2ms pre-process, 343.2ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
#block 5
# !python detect.py --weights "/content/yolov5/best.pt" --img 640 --conf 0.25 --source "/content/yolov5/test3.png"
image = cv2.imread(os.path.join("/content/yolov5/runs/detect/exp3/test3.png"))
plt.imshow(image) 
plt.show()
# Out:
# detect: weights=['/content/yolov5/best.pt'], source=/content/yolov5/test3.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test3.png: 352x640 1 audi, 233.9ms
# Speed: 0.9ms pre-process, 233.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# block 6
# !python detect.py --weights "/content/yolov5/best.pt" --img 640 --conf 0.25 --source "/content/yolov5/test4.jpg"
image = cv2.imread(os.path.join("/content/yolov5/runs/detect/exp4/test4.jpg"))
plt.imshow(image) 
plt.show()
# Out:
# detect: weights=['/content/yolov5/best.pt'], source=/content/yolov5/test4.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test4.jpg: 480x640 1 toyota, 321.9ms
# Speed: 2.5ms pre-process, 321.9ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# block 7
# !python detect.py --weights "/content/yolov5/best.pt" --img 640 --conf 0.25 --source "/content/yolov5/test5.png"
image = cv2.imread(os.path.join("/content/yolov5/runs/detect/exp5/test5.png"))
plt.imshow(image) 
plt.show()
# Out:
# detect: weights=['/content/yolov5/best.pt'], source=/content/yolov5/test5.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test5.png: 192x640 1 honda, 1 toyota, 150.3ms
# Speed: 1.1ms pre-process, 150.3ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5
